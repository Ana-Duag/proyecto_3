# %% [markdown]
# CREAMOS CELDAS INDIVIDUALES PARA TENER A GOLPE DE VISTA LO QUE VAMOS HACIENDO TODAS

# %% [markdown]
# Creamos una función para elegir Scrum Master

# %%
import random

def elegir_finalista():
    candidatas = ["Yeri", "Ana", "Samai"]
    return random.choice(candidatas)

if __name__ == "__main__":
    print("La finalista es:", elegir_finalista())
# Out:
# La finalista es: Samai

# %%
import pandas as pd

df = pd.read_csv("ABC_data.csv", index_col = 0)

df
# Out:
#      age attrition businesstravel    dailyrate                department  \
# 0     51        No            NaN  2015.722222                       NaN
# 1     52        No            NaN  2063.388889                       NaN
# 2     42        No  travel_rarely  1984.253968   Research & Development
# 3     47        No  travel_rarely  1771.404762                       NaN
# 4     46        No            NaN  1582.771346                       NaN
# ...   ..       ...            ...          ...                       ...
# 1673  43        No            NaN   488.944444                       NaN
# 1674  47        No            NaN  1973.984127                       NaN
# 1675  29        No  travel_rarely   290.035510                       NaN
# 1676  47        No  travel_rarely  1032.487286                       NaN
# 1677  32        No            NaN   556.256661                       NaN
#
#       distancefromhome  education    educationfield  employeecount  \
# 0                    6          3               NaN              1
# 1                    1          4     Life Sciences              1
# 2                    4          2  Technical Degree              1
# 3                    2          4           Medical              1
# 4                    3          3  Technical Degree              1
# ...                ...        ...               ...            ...
# 1673               -26          3           Medical              1
# 1674                26          4               NaN              1
# 1675                15          3               NaN              1
# 1676                 4          3     Life Sciences              1
# 1677                 2          2     Life Sciences              1
#
#       employeenumber  ...  yearsatcompany  yearsincurrentrole  \
# 0                  1  ...              20                 NaN
# 1                  2  ...              33                 NaN
# 2                  3  ...              22                 NaN
# 3                  4  ...              20                 NaN
# 4                  5  ...              19                 NaN
# ...              ...  ...             ...                 ...
# 1673             824  ...               3                 NaN
# 1674            1087  ...               5                 NaN
# 1675             528  ...               6                 NaN
# 1676              76  ...              22                 NaN
# 1677             401  ...               8                 NaN
#
#       yearssincelastpromotion  yearswithcurrmanager  sameasmonthlyincome  \
# 0                          15                    15            16280,83$
# 1                          11                     9                  NaN
# 2                          11                    15                  NaN
# 3                           5                     6            14307,50$
# 4                           2                     8            12783,92$
# ...                       ...                   ...                  ...
# 1673                        1                     2             3949,17$
# 1674                        1                     0            15943,72$
# 1675                        1                     5                  NaN
# 1676                       14                    10             8339,32$
# 1677                        0                     7                  NaN
#
#      datebirth      salary                       roledepartament  \
# 0         1972  195370,00$                                   NaN
# 1         1971  199990,00$                                   NaN
# 2         1981  192320,00$   ManaGER  -  Research & Development
# 3         1976  171690,00$                                   NaN
# 4         1977         NaN                                   NaN
# ...        ...         ...                                   ...
# 1673      1980         NaN                                   NaN
# 1674      1976  191324,62$                                   NaN
# 1675      1994   28111,13$                                   NaN
# 1676      1976  100071,84$                                   NaN
# 1677      1991   53914,11$                                   NaN
#
#      numberchildren remotework
# 0               NaN        Yes
# 1               NaN          1
# 2               NaN          1
# 3               NaN      False
# 4               NaN          0
# ...             ...        ...
# 1673            NaN        Yes
# 1674            NaN      False
# 1675            NaN      False
# 1676            NaN        Yes
# 1677            NaN          0
#
# [1678 rows x 41 columns]

# %% [markdown]
# #### ANÁLISIS EXPLORATORIO DE DATOS

# %% [markdown]
# Este es un primer EDA sin haber tratado los nulos, las columnas redundantes y los resultados inconsistentes, por lo que si bien es una primera aproximación de los datos que tenemos, los resultados reales podrían estar bastante alejados de estos resultados. Es necesario en cada momento contextualizar las condiciones en las que se han obtenido los datos.

# %%
# importamos las librerías que necesitamos

# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np
from IPython.display import display

# Imputación de nulos usando métodos avanzados estadísticos
# -----------------------------------------------------------------------
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer

# Librerías de visualización
# -----------------------------------------------------------------------
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# ver todas las columnas
pd.set_option('display.max_columns', None)

# %%
# ver todas las filas
pd.set_option('display.max_rows', None)

# %%
df.head()
# Out:
#   age attrition businesstravel    dailyrate                department  \
# 0  51        No            NaN  2015.722222                       NaN
# 1  52        No            NaN  2063.388889                       NaN
# 2  42        No  travel_rarely  1984.253968   Research & Development
# 3  47        No  travel_rarely  1771.404762                       NaN
# 4  46        No            NaN  1582.771346                       NaN
#
#    distancefromhome  education    educationfield  employeecount  \
# 0                 6          3               NaN              1
# 1                 1          4     Life Sciences              1
# 2                 4          2  Technical Degree              1
# 3                 2          4           Medical              1
# 4                 3          3  Technical Degree              1
#
#    employeenumber  environmentsatisfaction  gender  hourlyrate  \
# 0               1                        1       0         NaN
# 1               2                        3       0         NaN
# 2               3                        3       0         NaN
# 3               4                        1       1         NaN
# 4               5                        1       1         NaN
#
#    jobinvolvement  joblevel              jobrole  jobsatisfaction  \
# 0               3         5   resEArch DIREcToR                 3
# 1               2         5             ManAGeR                 3
# 2               3         5             ManaGER                 4
# 3               3         4   ReseArCH DIrECtOr                 3
# 4               4         4     sAleS EXECUtIve                 1
#
#   maritalstatus monthlyincome monthlyrate  numcompaniesworked over18 overtime  \
# 0           NaN     16280,83$   42330,17$                   7      Y       No
# 1           NaN           NaN   43331,17$                   0    NaN      NaN
# 2       Married           NaN   41669,33$                   1    NaN       No
# 3       Married     14307,50$   37199,50$                   3      Y      NaN
# 4      Divorced     12783,92$   33238,20$                   2      Y       No
#
#    percentsalaryhike performancerating  relationshipsatisfaction  \
# 0                 13               3,0                         3
# 1                 14               3,0                         1
# 2                 11               3,0                         4
# 3                 19               3,0                         2
# 4                 12               3,0                         4
#
#   standardhours  stockoptionlevel totalworkingyears  trainingtimeslastyear  \
# 0     Full Time                 0               NaN                      5
# 1           NaN                 1              34,0                      5
# 2           NaN                 0              22,0                      3
# 3     Full Time                 2               NaN                      2
# 4           NaN                 1               NaN                      5
#
#   worklifebalance  yearsatcompany yearsincurrentrole  yearssincelastpromotion  \
# 0             3,0              20                NaN                       15
# 1             3,0              33                NaN                       11
# 2             NaN              22                NaN                       11
# 3             NaN              20                NaN                        5
# 4             3,0              19                NaN                        2
#
#    yearswithcurrmanager sameasmonthlyincome  datebirth      salary  \
# 0                    15           16280,83$       1972  195370,00$
# 1                     9                 NaN       1971  199990,00$
# 2                    15                 NaN       1981  192320,00$
# 3                     6           14307,50$       1976  171690,00$
# 4                     8           12783,92$       1977         NaN
#
#                         roledepartament  numberchildren remotework
# 0                                   NaN             NaN        Yes
# 1                                   NaN             NaN          1
# 2   ManaGER  -  Research & Development              NaN          1
# 3                                   NaN             NaN      False
# 4                                   NaN             NaN          0

# %% [markdown]
# Necesitamos hacer una copia del dataframe porque se van a convertir las columnas object que sean numéricas para realizar un EDA más exacto.  Y queremos que nuestro dataframe de inicio quede intacto.

# %%
import pandas as pd
import warnings

def limpiar_df(df):
    """
    Convierte automáticamente columnas object que sean numéricas o fechas.
    Modifica el DataFrame recibido.
    Ignora warnings de pandas sobre inferencia de formato de fechas.
    """
    # Ignorar UserWarning de pandas
    warnings.filterwarnings("ignore", category=UserWarning)
    
    for col in df.select_dtypes(include='object').columns:
        # Intentar convertir a número
        try:
            df[col] = pd.to_numeric(df[col], errors='raise')
            continue
        except:
            pass
        # Intentar convertir a fecha
        try:
            df[col] = pd.to_datetime(df[col], errors='raise', dayfirst=False)
        except:
            pass  # Si falla, dejamos como object (categórica)
    
    # Restaurar warnings
    warnings.resetwarnings()
    
    return df


# Crear copia
df_limpio = df.copy()

# Limpiar la copia
limpiar_df(df_limpio)

# Ahora df_limpio tiene columnas numéricas y fechas convertidas,
# y las columnas categóricas reales siguen siendo object

# %%
# Función para EDA completo

def eda(df):
    """
    Realiza un análisis exploratorio de datos sobre un DataFrame ya limpio:
    - Primeras filas
    - Dimensiones
    - Tipos de datos
    - Estadísticas numéricas y categóricas
    - Valores nulos
    - Filas duplicadas
    - Valores únicos
    - Distribución de variables categóricas
    - Resumen general
    """
    print("ANÁLISIS EXPLORATORIO DE DATOS\n")

    print("Primeras 10 filas:")
    display(df.head(10))

    print("\nDimensiones:")
    print(df.shape)

    print("\nInformación general:")
    df.info()

    print("\nTipos de datos por columna:")
    print(df.dtypes)

    # Columnas numéricas
    num_cols = df.select_dtypes(include='number').columns
    if len(num_cols) > 0:
        print("\nEstadísticas numéricas:")
        display(df[num_cols].describe().T)

    # Columnas categóricas reales
    cat_cols = df.select_dtypes(include='object').columns
    if len(cat_cols) > 0:
        print("\nEstadísticas categóricas:")
        display(df[cat_cols].describe())

    # Valores nulos
    print("\nValores nulos:")
    display(pd.DataFrame({
        "Conteo": df.isnull().sum(),
        "Porcentaje": (df.isnull().sum()/len(df)*100).round(2)
    }).sort_values(by="Porcentaje", ascending=False))

    # Filas duplicadas
    print("\nFilas duplicadas:", df.duplicated().sum())

    # Valores únicos
    print("\nValores únicos por columna:")
    display(df.nunique().sort_values(ascending=False))

    # Distribución de variables categóricas
    for col in cat_cols:
        print(f"\nColumna: {col}")
        display(df[col].value_counts().head())

    # Resumen general
    resumen = pd.DataFrame({
        "Columna": df.columns,
        "Dtype": df.dtypes.astype(str),
        "Valores únicos": df.nunique().values,
        "% Nulos": (df.isnull().sum()/len(df)*100).round(2).values
    })
    print("\nResumen general de columnas:")
    display(resumen)

    return resumen

# %%
# df_limpio es la copia, df original queda intacto
resumen = eda(df_limpio)   # Hacemos el EDA antes de eliminar columnas
# Out:
# ANÁLISIS EXPLORATORIO DE DATOS
#
# Primeras 10 filas:
#   age attrition     businesstravel    dailyrate                department  \
# 0  51        No                NaN  2015.722222                       NaN
# 1  52        No                NaN  2063.388889                       NaN
# 2  42        No      travel_rarely  1984.253968   Research & Development
# 3  47        No      travel_rarely  1771.404762                       NaN
# 4  46        No                NaN  1582.771346                       NaN
# 5  48        No                NaN  1771.920635   Research & Development
# 6  59        No                NaN  1032.487286                       NaN
# 7  42        No      travel_rarely   556.256661                       NaN
# 8  41        No                NaN  1712.182540                       NaN
# 9  41        No  travel_frequently  1973.984127                       NaN
#
#    distancefromhome  education    educationfield  employeecount  \
# 0                 6          3               NaN              1
# 1                 1          4     Life Sciences              1
# 2                 4          2  Technical Degree              1
# 3                 2          4           Medical              1
# 4                 3          3  Technical Degree              1
# 5                22          3           Medical              1
# 6                25          3     Life Sciences              1
# 7                 1          1               NaN              1
# 8                 2          5               NaN              1
# 9                 9          3               NaN              1
#
#    employeenumber  environmentsatisfaction  gender  hourlyrate  \
# 0               1                        1       0         NaN
# 1               2                        3       0         NaN
# 2               3                        3       0         NaN
# 3               4                        1       1         NaN
# 4               5                        1       1         NaN
# 5               6                        4       1         NaN
# 6               7                        1       1         NaN
# 7               8                        2       0   69.532083
# 8               9                        2       1         NaN
# 9              10                        1       0         NaN
#
#    jobinvolvement  joblevel              jobrole  jobsatisfaction  \
# 0               3         5   resEArch DIREcToR                 3
# 1               2         5             ManAGeR                 3
# 2               3         5             ManaGER                 4
# 3               3         4   ReseArCH DIrECtOr                 3
# 4               4         4     sAleS EXECUtIve                 1
# 5               3         4             MANAger                 4
# 6               3         3     Sales ExeCutIVe                 1
# 7               3         2     Sales eXEcUTiVe                 3
# 8               3         4             mANAGEr                 1
# 9               3         5   reSEaRCH DIrectoR                 3
#
#   maritalstatus monthlyincome monthlyrate  numcompaniesworked over18 overtime  \
# 0           NaN     16280,83$   42330,17$                   7      Y       No
# 1           NaN           NaN   43331,17$                   0    NaN      NaN
# 2       Married           NaN   41669,33$                   1    NaN       No
# 3       Married     14307,50$   37199,50$                   3      Y      NaN
# 4      Divorced     12783,92$   33238,20$                   2      Y       No
# 5           NaN     14311,67$   37210,33$                   3    NaN       No
# 6           NaN      8339,32$   21682,23$                   7      Y      NaN
# 7       Married           NaN   11681,39$                   1    NaN       No
# 8       Married     13829,17$   35955,83$                   7    NaN       No
# 9           NaN     15943,72$   41453,67$                   2    NaN       No
#
#    percentsalaryhike performancerating  relationshipsatisfaction  \
# 0                 13               3,0                         3
# 1                 14               3,0                         1
# 2                 11               3,0                         4
# 3                 19               3,0                         2
# 4                 12               3,0                         4
# 5                 11               3,0                         2
# 6                 11               3,0                         4
# 7                 25               4,0                         3
# 8                 16               3,0                         2
# 9                 17               3,0                         2
#
#   standardhours  stockoptionlevel totalworkingyears  trainingtimeslastyear  \
# 0     Full Time                 0               NaN                      5
# 1           NaN                 1              34,0                      5
# 2           NaN                 0              22,0                      3
# 3     Full Time                 2               NaN                      2
# 4           NaN                 1               NaN                      5
# 5           NaN                 1               NaN                      3
# 6     Part Time                 0              28,0                      3
# 7     Part Time                 0              20,0                      3
# 8     Full Time                 1              22,0                      2
# 9           NaN                 1              21,0                      2
#
#   worklifebalance  yearsatcompany yearsincurrentrole  yearssincelastpromotion  \
# 0             3,0              20                NaN                       15
# 1             3,0              33                NaN                       11
# 2             NaN              22                NaN                       11
# 3             NaN              20                NaN                        5
# 4             3,0              19                NaN                        2
# 5             3,0              22                NaN                        4
# 6             2,0              21                NaN                        7
# 7             3,0              20                NaN                       11
# 8             3,0              18                NaN                       11
# 9             4,0              18                NaN                        0
#
#    yearswithcurrmanager sameasmonthlyincome  datebirth      salary  \
# 0                    15           16280,83$       1972  195370,00$
# 1                     9                 NaN       1971  199990,00$
# 2                    15                 NaN       1981  192320,00$
# 3                     6           14307,50$       1976  171690,00$
# 4                     8           12783,92$       1977         NaN
# 5                     7           14311,67$       1975         NaN
# 6                     9            8339,32$       1964  100071,84$
# 7                     6                 NaN       1981   53914,11$
# 8                     8           13829,17$       1982  165950,00$
# 9                    11           15943,72$       1982         NaN
#
#                         roledepartament  numberchildren remotework
# 0                                   NaN             NaN        Yes
# 1                                   NaN             NaN          1
# 2   ManaGER  -  Research & Development              NaN          1
# 3                                   NaN             NaN      False
# 4                                   NaN             NaN          0
# 5   MANAger  -  Research & Development              NaN        Yes
# 6                                   NaN             NaN       True
# 7                                   NaN             NaN          0
# 8                                   NaN             NaN       True
# 9                                   NaN             NaN          0
# Dimensiones:
# (1678, 41)
#
# Información general:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1678 entries, 0 to 1677
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       1678 non-null   object
#  1   attrition                 1678 non-null   object
#  2   businesstravel            877 non-null    object
#  3   dailyrate                 1678 non-null   float64
#  4   department                312 non-null    object
#  5   distancefromhome          1678 non-null   int64
#  6   education                 1678 non-null   int64
#  7   educationfield            904 non-null    object
#  8   employeecount             1678 non-null   int64
#  9   employeenumber            1678 non-null   int64
#  10  environmentsatisfaction   1678 non-null   int64
#  11  gender                    1678 non-null   int64
#  12  hourlyrate                411 non-null    float64
#  13  jobinvolvement            1678 non-null   int64
#  14  joblevel                  1678 non-null   int64
#  15  jobrole                   1678 non-null   object
#  16  jobsatisfaction           1678 non-null   int64
#  17  maritalstatus             1003 non-null   object
#  18  monthlyincome             1189 non-null   object
#  19  monthlyrate               1678 non-null   object
#  20  numcompaniesworked        1678 non-null   int64
#  21  over18                    740 non-null    object
#  22  overtime                  982 non-null    object
#  23  percentsalaryhike         1678 non-null   int64
#  24  performancerating         1478 non-null   object
#  25  relationshipsatisfaction  1678 non-null   int64
#  26  standardhours             1327 non-null   object
#  27  stockoptionlevel          1678 non-null   int64
#  28  totalworkingyears         1129 non-null   object
#  29  trainingtimeslastyear     1678 non-null   int64
#  30  worklifebalance           1564 non-null   object
#  31  yearsatcompany            1678 non-null   int64
#  32  yearsincurrentrole        35 non-null     object
#  33  yearssincelastpromotion   1678 non-null   int64
#  34  yearswithcurrmanager      1678 non-null   int64
#  35  sameasmonthlyincome       1189 non-null   object
#  36  datebirth                 1678 non-null   int64
#  37  salary                    1393 non-null   object
#  38  roledepartament           312 non-null    object
#  39  numberchildren            0 non-null      float64
#  40  remotework                1678 non-null   object
# dtypes: float64(3), int64(18), object(20)
# memory usage: 550.6+ KB
#
# Tipos de datos por columna:
# age                          object
# attrition                    object
# businesstravel               object
# dailyrate                   float64
# department                   object
# distancefromhome              int64
# education                     int64
# educationfield               object
# employeecount                 int64
# employeenumber                int64
# environmentsatisfaction       int64
# gender                        int64
# hourlyrate                  float64
# jobinvolvement                int64
# joblevel                      int64
# jobrole                      object
# jobsatisfaction               int64
# maritalstatus                object
# monthlyincome                object
# monthlyrate                  object
# numcompaniesworked            int64
# over18                       object
# overtime                     object
# percentsalaryhike             int64
# performancerating            object
# relationshipsatisfaction      int64
# standardhours                object
# stockoptionlevel              int64
# totalworkingyears            object
# trainingtimeslastyear         int64
# worklifebalance              object
# yearsatcompany                int64
# yearsincurrentrole           object
# yearssincelastpromotion       int64
# yearswithcurrmanager          int64
# sameasmonthlyincome          object
# datebirth                     int64
# salary                       object
# roledepartament              object
# numberchildren              float64
# remotework                   object
# dtype: object
#
# Estadísticas numéricas:
#                            count         mean         std          min  \
# dailyrate                 1678.0   668.079714  470.787298   104.103175
# distancefromhome          1678.0     4.504172   14.652066   -49.000000
# education                 1678.0     2.932658    1.024270     1.000000
# employeecount             1678.0     1.000000    0.000000     1.000000
# employeenumber            1678.0   809.859952  467.084867     1.000000
# environmentsatisfaction   1678.0     4.264005    6.912695     1.000000
# gender                    1678.0     0.398689    0.489774     0.000000
# hourlyrate                 411.0    83.140768   57.272101    13.012897
# jobinvolvement            1678.0     2.740763    0.710359     1.000000
# joblevel                  1678.0     2.064362    1.099425     1.000000
# jobsatisfaction           1678.0     2.743147    1.105172     1.000000
# numcompaniesworked        1678.0     2.670441    2.501133     0.000000
# percentsalaryhike         1678.0    15.154350    3.649607    11.000000
# relationshipsatisfaction  1678.0     2.700238    1.079494     1.000000
# stockoptionlevel          1678.0     0.787843    0.843252     0.000000
# trainingtimeslastyear     1678.0     2.795590    1.288657     0.000000
# yearsatcompany            1678.0     7.124553    6.173837     0.000000
# yearssincelastpromotion   1678.0     2.241955    3.246554     0.000000
# yearswithcurrmanager      1678.0     4.200238    3.554224     0.000000
# datebirth                 1678.0  1986.047080    9.154908  1963.000000
# numberchildren               0.0          NaN         NaN          NaN
#
#                                   25%          50%          75%          max
# dailyrate                  290.035510   556.256661   971.956349  2063.388889
# distancefromhome             2.000000     5.000000    11.000000    29.000000
# education                    2.000000     3.000000     4.000000     5.000000
# employeecount                1.000000     1.000000     1.000000     1.000000
# employeenumber             403.250000   813.500000  1215.750000  1614.000000
# environmentsatisfaction      2.000000     3.000000     4.000000    49.000000
# gender                       0.000000     0.000000     1.000000     1.000000
# hourlyrate                  36.254439    69.532083   116.987103   255.963294
# jobinvolvement               2.000000     3.000000     3.000000     4.000000
# joblevel                     1.000000     2.000000     3.000000     5.000000
# jobsatisfaction              2.000000     3.000000     4.000000     4.000000
# numcompaniesworked           1.000000     2.000000     4.000000     9.000000
# percentsalaryhike           12.000000    14.000000    18.000000    25.000000
# relationshipsatisfaction     2.000000     3.000000     4.000000     4.000000
# stockoptionlevel             0.000000     1.000000     1.000000     3.000000
# trainingtimeslastyear        2.000000     3.000000     3.000000     6.000000
# yearsatcompany               3.000000     5.000000     9.000000    40.000000
# yearssincelastpromotion      0.000000     1.000000     3.000000    15.000000
# yearswithcurrmanager         2.000000     3.000000     7.000000    17.000000
# datebirth                 1980.000000  1987.000000  1993.000000  2005.000000
# numberchildren                    NaN          NaN          NaN          NaN
# Estadísticas categóricas:
#          age attrition businesstravel                department  \
# count   1678      1678            877                       312
# unique    54         2              3                         3
# top       35        No  travel_rarely   Research & Development
# freq      88      1406            616                       203
#
#        educationfield    jobrole maritalstatus monthlyincome monthlyrate  \
# count             904       1678          1003          1189        1678
# unique              6       1579             5           493         673
# top     Life Sciences   mANager        Married      2342,59$   11681,39$
# freq              367          5           419           228         326
#
#        over18 overtime performancerating standardhours totalworkingyears  \
# count     740      982              1478          1327              1129
# unique      1        2                 2             2                40
# top         Y       No               3,0     Part Time              10,0
# freq      740      714              1257           927               151
#
#        worklifebalance yearsincurrentrole sameasmonthlyincome     salary  \
# count             1564                 35                1189       1393
# unique               4                 10                 493        583
# top                3,0                2,0            2342,59$  53914,11$
# freq               946                 12                 228        270
#
#                     roledepartament remotework
# count                           312       1678
# unique                          301          5
# top      Sales exECutIVE  -  Sales           1
# freq                              2        375
# Valores nulos:
#                           Conteo  Porcentaje
# numberchildren              1678      100.00
# yearsincurrentrole          1643       97.91
# roledepartament             1366       81.41
# department                  1366       81.41
# hourlyrate                  1267       75.51
# over18                       938       55.90
# businesstravel               801       47.74
# educationfield               774       46.13
# overtime                     696       41.48
# maritalstatus                675       40.23
# totalworkingyears            549       32.72
# monthlyincome                489       29.14
# sameasmonthlyincome          489       29.14
# standardhours                351       20.92
# salary                       285       16.98
# performancerating            200       11.92
# worklifebalance              114        6.79
# employeecount                  0        0.00
# education                      0        0.00
# distancefromhome               0        0.00
# dailyrate                      0        0.00
# attrition                      0        0.00
# age                            0        0.00
# environmentsatisfaction        0        0.00
# employeenumber                 0        0.00
# percentsalaryhike              0        0.00
# numcompaniesworked             0        0.00
# monthlyrate                    0        0.00
# gender                         0        0.00
# jobinvolvement                 0        0.00
# joblevel                       0        0.00
# jobrole                        0        0.00
# jobsatisfaction                0        0.00
# yearsatcompany                 0        0.00
# trainingtimeslastyear          0        0.00
# relationshipsatisfaction       0        0.00
# stockoptionlevel               0        0.00
# datebirth                      0        0.00
# yearswithcurrmanager           0        0.00
# yearssincelastpromotion        0        0.00
# remotework                     0        0.00
# Filas duplicadas: 64
#
# Valores únicos por columna:
# employeenumber              1614
# jobrole                     1579
# monthlyrate                  673
# dailyrate                    673
# salary                       583
# monthlyincome                493
# sameasmonthlyincome          493
# roledepartament              301
# hourlyrate                   194
# distancefromhome              69
# age                           54
# datebirth                     43
# totalworkingyears             40
# environmentsatisfaction       38
# yearsatcompany                37
# yearswithcurrmanager          18
# yearssincelastpromotion       16
# percentsalaryhike             15
# numcompaniesworked            10
# yearsincurrentrole            10
# trainingtimeslastyear          7
# educationfield                 6
# education                      5
# remotework                     5
# maritalstatus                  5
# joblevel                       5
# worklifebalance                4
# jobsatisfaction                4
# relationshipsatisfaction       4
# stockoptionlevel               4
# jobinvolvement                 4
# department                     3
# businesstravel                 3
# standardhours                  2
# attrition                      2
# overtime                       2
# gender                         2
# performancerating              2
# employeecount                  1
# over18                         1
# numberchildren                 0
# dtype: int64
# Columna: age
# age
# 35    88
# 31    88
# 34    86
# 29    82
# 36    79
# Name: count, dtype: int64
# Columna: attrition
# attrition
# No     1406
# Yes     272
# Name: count, dtype: int64
# Columna: businesstravel
# businesstravel
# travel_rarely        616
# travel_frequently    168
# non-travel            93
# Name: count, dtype: int64
# Columna: department
# department
# Research & Development     203
# Sales                       93
# Human Resources             16
# Name: count, dtype: int64
# Columna: educationfield
# educationfield
# Life Sciences       367
# Medical             286
# Marketing           106
# Technical Degree     70
# Other                63
# Name: count, dtype: int64
# Columna: jobrole
# jobrole
# mANager     5
# mAnageR     3
# ManagEr     3
# mAnaGeR     3
# ManageR     3
# Name: count, dtype: int64
# Columna: maritalstatus
# maritalstatus
# Married     419
# Single      343
# Divorced    194
# Marreid      36
# divorced     11
# Name: count, dtype: int64
# Columna: monthlyincome
# monthlyincome
# 2342,59$     228
# 4492,84$     227
# 8339,32$     105
# 12783,92$     42
# 15943,72$     25
# Name: count, dtype: int64
# Columna: monthlyrate
# monthlyrate
# 11681,39$    326
# 6090,75$     308
# 21682,23$    150
# 33238,20$     55
# 41453,67$     38
# Name: count, dtype: int64
# Columna: over18
# over18
# Y    740
# Name: count, dtype: int64
# Columna: overtime
# overtime
# No     714
# Yes    268
# Name: count, dtype: int64
# Columna: performancerating
# performancerating
# 3,0    1257
# 4,0     221
# Name: count, dtype: int64
# Columna: standardhours
# standardhours
# Part Time    927
# Full Time    400
# Name: count, dtype: int64
# Columna: totalworkingyears
# totalworkingyears
# 10,0    151
# 6,0      88
# 8,0      86
# 9,0      71
# 5,0      68
# Name: count, dtype: int64
# Columna: worklifebalance
# worklifebalance
# 3,0    946
# 2,0    374
# 4,0    162
# 1,0     82
# Name: count, dtype: int64
# Columna: yearsincurrentrole
# yearsincurrentrole
# 2,0    12
# 7,0     5
# 0,0     4
# 4,0     3
# 1,0     3
# Name: count, dtype: int64
# Columna: sameasmonthlyincome
# sameasmonthlyincome
# 2342,59$     228
# 4492,84$     227
# 8339,32$     105
# 12783,92$     42
# 15943,72$     25
# Name: count, dtype: int64
# Columna: salary
# salary
# 53914,11$     270
# 28111,13$     255
# 100071,84$    122
# 153407,07$     45
# 191324,62$     28
# Name: count, dtype: int64
# Columna: roledepartament
# roledepartament
# Sales exECutIVE  -  Sales                                2
# humAN resoURCEs  -  Human Resources                      2
# labORAtoRy tEcHNICIAN  -  Research & Development         2
# hEalthCaRe reprEseNTaTiVe  -  Research & Development     2
# LaBoratory TECHnICIAn  -  Research & Development         2
# Name: count, dtype: int64
# Columna: remotework
# remotework
# 1        375
# True     362
# False    318
# 0        318
# Yes      305
# Name: count, dtype: int64
# Resumen general de columnas:
#                                            Columna    Dtype  Valores únicos  \
# age                                            age   object              54
# attrition                                attrition   object               2
# businesstravel                      businesstravel   object               3
# dailyrate                                dailyrate  float64             673
# department                              department   object               3
# distancefromhome                  distancefromhome    int64              69
# education                                education    int64               5
# educationfield                      educationfield   object               6
# employeecount                        employeecount    int64               1
# employeenumber                      employeenumber    int64            1614
# environmentsatisfaction    environmentsatisfaction    int64              38
# gender                                      gender    int64               2
# hourlyrate                              hourlyrate  float64             194
# jobinvolvement                      jobinvolvement    int64               4
# joblevel                                  joblevel    int64               5
# jobrole                                    jobrole   object            1579
# jobsatisfaction                    jobsatisfaction    int64               4
# maritalstatus                        maritalstatus   object               5
# monthlyincome                        monthlyincome   object             493
# monthlyrate                            monthlyrate   object             673
# numcompaniesworked              numcompaniesworked    int64              10
# over18                                      over18   object               1
# overtime                                  overtime   object               2
# percentsalaryhike                percentsalaryhike    int64              15
# performancerating                performancerating   object               2
# relationshipsatisfaction  relationshipsatisfaction    int64               4
# standardhours                        standardhours   object               2
# stockoptionlevel                  stockoptionlevel    int64               4
# totalworkingyears                totalworkingyears   object              40
# trainingtimeslastyear        trainingtimeslastyear    int64               7
# worklifebalance                    worklifebalance   object               4
# yearsatcompany                      yearsatcompany    int64              37
# yearsincurrentrole              yearsincurrentrole   object              10
# yearssincelastpromotion    yearssincelastpromotion    int64              16
# yearswithcurrmanager          yearswithcurrmanager    int64              18
# sameasmonthlyincome            sameasmonthlyincome   object             493
# datebirth                                datebirth    int64              43
# salary                                      salary   object             583
# roledepartament                    roledepartament   object             301
# numberchildren                      numberchildren  float64               0
# remotework                              remotework   object               5
#
#                           % Nulos
# age                          0.00
# attrition                    0.00
# businesstravel              47.74
# dailyrate                    0.00
# department                  81.41
# distancefromhome             0.00
# education                    0.00
# educationfield              46.13
# employeecount                0.00
# employeenumber               0.00
# environmentsatisfaction      0.00
# gender                       0.00
# hourlyrate                  75.51
# jobinvolvement               0.00
# joblevel                     0.00
# jobrole                      0.00
# jobsatisfaction              0.00
# maritalstatus               40.23
# monthlyincome               29.14
# monthlyrate                  0.00
# numcompaniesworked           0.00
# over18                      55.90
# overtime                    41.48
# percentsalaryhike            0.00
# performancerating           11.92
# relationshipsatisfaction     0.00
# standardhours               20.92
# stockoptionlevel             0.00
# totalworkingyears           32.72
# trainingtimeslastyear        0.00
# worklifebalance              6.79
# yearsatcompany               0.00
# yearsincurrentrole          97.91
# yearssincelastpromotion      0.00
# yearswithcurrmanager         0.00
# sameasmonthlyincome         29.14
# datebirth                    0.00
# salary                      16.98
# roledepartament             81.41
# numberchildren             100.00
# remotework                   0.00

# %% [markdown]
# ### 🗑️ Plan de eliminación de columnas redundantes
#
# 💰 **monthlyincome, sameasmonthlyincome y salary**
# - 📊 Todas parecen expresar ingresos mensuales o anuales en distintas unidades/formatos.
# - 🔁 `sameasmonthlyincome` explícitamente es un duplicado de `monthlyincome`.
# ✅ Nos quedamos con **monthlyincome** y **salary**
# ❌ Eliminamos **sameasmonthlyincome**
#
# ---
#
# 🏢 **department, roledepartament y jobrole**
# - ⚠️ `roledepartament` mezcla el rol con el departamento (ejemplo: *Manager - Research & Development*), mientras que `department` y `jobrole` ya lo tienen separado.
# ✅ Nos quedamos con **department** y **jobrole**
# ❌ Eliminamos **roledepartament**
# 💡 *Más adelante podemos fusionar `department` y `jobrole` si es necesario.*
#
# ---
#
# 👥 **employeecount y employeenumber**
# - 🔂 `employeecount` es siempre 1 → columna inútil.
# - 🆔 `employeenumber` parece ser solo un identificador único → no aporta al análisis predictivo.
# ❌ Eliminamos **employeecount**
#
# ---
#
# 🎂 **age y datebirth**
# - 📐 Son equivalentes: de `datebirth` se puede calcular la edad.
# ❌ Eliminamos **age**
#
# ---
#
# 👶 **numberchildren**
# - 🚫 Está completamente vacío (0 valores válidos).
# ❌ Eliminamos **numberchildren**

# %%
# Función para eliminar columnas redundantes

def drop_redundant_columns(df_clean):
    cols_to_drop = [
        "sameasmonthlyincome",
        "roledepartament",
        "employeecount",
        "age",
        "numberchildren"
    ]
    
    # Mostrar solo las columnas que existen realmente
    existing_cols = [c for c in cols_to_drop if c in df_clean.columns]
    print("Eliminando columnas:", existing_cols)
    
    # Eliminar columnas existentes
    df_clean = df_clean.drop(columns=existing_cols)
    
    return df_clean

# %%
# Ahora eliminar columnas redundantes
df_limpio = drop_redundant_columns(df_limpio)
# Out:
# Eliminando columnas: ['sameasmonthlyincome', 'roledepartament', 'employeecount', 'age', 'numberchildren']

# %%
# Mostrar DataFrame limpio final
display(df_limpio.head())
# Out:
#   attrition businesstravel    dailyrate                department  \
# 0        No            NaN  2015.722222                       NaN
# 1        No            NaN  2063.388889                       NaN
# 2        No  travel_rarely  1984.253968   Research & Development
# 3        No  travel_rarely  1771.404762                       NaN
# 4        No            NaN  1582.771346                       NaN
#
#    distancefromhome  education    educationfield  employeenumber  \
# 0                 6          3               NaN               1
# 1                 1          4     Life Sciences               2
# 2                 4          2  Technical Degree               3
# 3                 2          4           Medical               4
# 4                 3          3  Technical Degree               5
#
#    environmentsatisfaction  gender  hourlyrate  jobinvolvement  joblevel  \
# 0                        1       0         NaN               3         5
# 1                        3       0         NaN               2         5
# 2                        3       0         NaN               3         5
# 3                        1       1         NaN               3         4
# 4                        1       1         NaN               4         4
#
#                jobrole  jobsatisfaction maritalstatus monthlyincome  \
# 0   resEArch DIREcToR                 3           NaN     16280,83$
# 1             ManAGeR                 3           NaN           NaN
# 2             ManaGER                 4       Married           NaN
# 3   ReseArCH DIrECtOr                 3       Married     14307,50$
# 4     sAleS EXECUtIve                 1      Divorced     12783,92$
#
#   monthlyrate  numcompaniesworked over18 overtime  percentsalaryhike  \
# 0   42330,17$                   7      Y       No                 13
# 1   43331,17$                   0    NaN      NaN                 14
# 2   41669,33$                   1    NaN       No                 11
# 3   37199,50$                   3      Y      NaN                 19
# 4   33238,20$                   2      Y       No                 12
#
#   performancerating  relationshipsatisfaction standardhours  stockoptionlevel  \
# 0               3,0                         3     Full Time                 0
# 1               3,0                         1           NaN                 1
# 2               3,0                         4           NaN                 0
# 3               3,0                         2     Full Time                 2
# 4               3,0                         4           NaN                 1
#
#   totalworkingyears  trainingtimeslastyear worklifebalance  yearsatcompany  \
# 0               NaN                      5             3,0              20
# 1              34,0                      5             3,0              33
# 2              22,0                      3             NaN              22
# 3               NaN                      2             NaN              20
# 4               NaN                      5             3,0              19
#
#   yearsincurrentrole  yearssincelastpromotion  yearswithcurrmanager  \
# 0                NaN                       15                    15
# 1                NaN                       11                     9
# 2                NaN                       11                    15
# 3                NaN                        5                     6
# 4                NaN                        2                     8
#
#    datebirth      salary remotework
# 0       1972  195370,00$        Yes
# 1       1971  199990,00$          1
# 2       1981  192320,00$          1
# 3       1976  171690,00$      False
# 4       1977         NaN          0

# %%
df_limpio
# Out:
#      attrition     businesstravel    dailyrate                department  \
# 0           No                NaN  2015.722222                       NaN
# 1           No                NaN  2063.388889                       NaN
# 2           No      travel_rarely  1984.253968   Research & Development
# 3           No      travel_rarely  1771.404762                       NaN
# 4           No                NaN  1582.771346                       NaN
# 5           No                NaN  1771.920635   Research & Development
# 6           No                NaN  1032.487286                       NaN
# 7           No      travel_rarely   556.256661                       NaN
# 8           No                NaN  1712.182540                       NaN
# 9           No  travel_frequently  1973.984127                       NaN
# 10          No         non-travel  2060.706349                       NaN
# 11          No      travel_rarely  1382.746032                       NaN
# 12          No                NaN  1362.523810                       NaN
# 13         Yes      travel_rarely  2016.547619                       NaN
# 14          No                NaN  1973.984127                       NaN
# 15          No      travel_rarely  1861.373016                       NaN
# 16         Yes      travel_rarely  1985.698413                       NaN
# 17          No      travel_rarely  1582.771346                       NaN
# 18          No                NaN   556.256661                       NaN
# 19          No      travel_rarely  1032.487286                       NaN
# 20          No         non-travel  1108.920635   Research & Development
# 21          No                NaN  1032.487286                       NaN
# 22          No                NaN  1032.487286                       NaN
# 23          No                NaN  1728.380952                       NaN
# 24          No      travel_rarely   639.785714                       NaN
# 25          No                NaN  1032.487286                       NaN
# 26         Yes                NaN  2047.500000                       NaN
# 27          No                NaN   556.256661                       NaN
# 28          No      travel_rarely   556.256661                       NaN
# 29          No         non-travel   412.801587                    Sales
# 30          No                NaN  1077.865079                    Sales
# 31          No                NaN  1032.487286   Research & Development
# 32          No      travel_rarely  1973.984127                       NaN
# 33          No                NaN   556.256661                       NaN
# 34          No      travel_rarely   556.256661                       NaN
# 35          No      travel_rarely  1032.487286                       NaN
# 36          No                NaN  1657.396825                       NaN
# 37          No                NaN   331.190476   Research & Development
# 38          No  travel_frequently  1059.190476                       NaN
# 39          No  travel_frequently  1080.753968                       NaN
# 40          No      travel_rarely   635.761905                       NaN
# 41          No      travel_rarely   487.087302                       NaN
# 42          No                NaN  1582.771346                       NaN
# 43         Yes      travel_rarely   290.035510                       NaN
# 44          No                NaN   476.150794                       NaN
# 45          No      travel_rarely   556.256661                       NaN
# 46          No                NaN  1032.487286                       NaN
# 47          No                NaN  1749.738095                       NaN
# 48          No                NaN   290.035510                       NaN
# 49          No      travel_rarely   556.256661                       NaN
# 50          No                NaN  1032.487286                       NaN
# 51          No                NaN  1582.771346                       NaN
# 52         Yes      travel_rarely  1063.317460                       NaN
# 53          No                NaN  1973.984127                       NaN
# 54          No         non-travel   556.256661                       NaN
# 55          No         non-travel   557.761905                       NaN
# 56          No                NaN   556.256661                       NaN
# 57          No                NaN   556.256661                       NaN
# 58          No      travel_rarely   608.936508                       NaN
# 59          No                NaN  1119.960317                       NaN
# 60          No                NaN   610.174603                       NaN
# 61          No                NaN   556.256661                       NaN
# 62          No                NaN   685.698413                       NaN
# 63          No  travel_frequently   556.256661                       NaN
# 64          No      travel_rarely  1441.658730   Research & Development
# 65          No      travel_rarely  1032.487286                       NaN
# 66          No      travel_rarely  1374.285714                    Sales
# 67          No      travel_rarely   556.256661                       NaN
# 68          No                NaN   556.256661                       NaN
# 69          No      travel_rarely   689.928571                       NaN
# 70          No         non-travel   556.256661   Research & Development
# 71          No                NaN  1032.487286                       NaN
# 72          No                NaN  1582.771346                       NaN
# 73          No  travel_frequently   488.531746                       NaN
# 74          No                NaN   290.035510                       NaN
# 75          No      travel_rarely  1032.487286                       NaN
# 76          No                NaN   556.256661   Research & Development
# 77          No      travel_rarely  1032.487286                       NaN
# 78          No                NaN   556.256661                       NaN
# 79          No      travel_rarely  1431.238095                       NaN
# 80          No      travel_rarely  1032.487286                       NaN
# 81         Yes      travel_rarely  1032.487286                       NaN
# 82          No                NaN  1032.487286                       NaN
# 83          No  travel_frequently  1032.487286                       NaN
# 84          No      travel_rarely  1964.960317                       NaN
# 85          No                NaN  1652.341270                       NaN
# 86          No      travel_rarely   991.817460   Research & Development
# 87          No                NaN  1187.539683                       NaN
# 88          No                NaN  1582.771346                       NaN
# 89          No                NaN   444.269841                       NaN
# 90          No      travel_rarely  1758.714286   Research & Development
# 91          No                NaN  1032.487286                       NaN
# 92          No                NaN   522.785714                       NaN
# 93          No                NaN  1032.487286   Research & Development
# 94          No      travel_rarely  1032.487286                       NaN
# 95          No                NaN   556.256661                    Sales
# 96          No                NaN   290.035510   Research & Development
# 97          No  travel_frequently   380.920635                       NaN
# 98         Yes                NaN  1973.984127                       NaN
# 99          No  travel_frequently  2047.706349                       NaN
# 100         No      travel_rarely   238.126984                       NaN
# 101         No      travel_rarely  1582.771346   Research & Development
# 102         No                NaN   556.256661                       NaN
# 103         No                NaN   290.035510                       NaN
# 104         No                NaN  1973.984127                       NaN
# 105         No                NaN   592.944444   Research & Development
# 106         No      travel_rarely  1075.285714                       NaN
# 107         No      travel_rarely  1032.487286                       NaN
# 108         No                NaN  1032.487286                       NaN
# 109         No                NaN   654.849206          Human Resources
# 110         No                NaN   242.253968                       NaN
# 111         No      travel_rarely  1032.487286                       NaN
# 112         No                NaN   316.952381                       NaN
# 113         No  travel_frequently   556.256661                       NaN
# 114         No      travel_rarely  1288.650794                       NaN
# 115         No                NaN   556.256661                       NaN
# 116         No      travel_rarely   827.460317                       NaN
# 117         No  travel_frequently  1032.487286                       NaN
# 118         No                NaN  1760.984127                       NaN
# 119         No                NaN   922.690476                       NaN
# 120         No                NaN  1988.380952   Research & Development
# 121         No      travel_rarely   556.256661                       NaN
# 122         No      travel_rarely   556.256661                    Sales
# 123         No                NaN  1032.487286                       NaN
# 124         No                NaN  1032.487286                       NaN
# 125         No      travel_rarely  1032.487286                       NaN
# 126         No      travel_rarely  1582.771346                       NaN
# 127         No                NaN   556.256661                       NaN
# 128         No      travel_rarely  1032.487286                       NaN
# 129         No      travel_rarely   575.404762                       NaN
# 130         No                NaN  1973.984127                       NaN
# 131         No      travel_rarely   277.642857   Research & Development
# 132        Yes      travel_rarely   290.035510                       NaN
# 133         No                NaN  1032.487286   Research & Development
# 134         No      travel_rarely  1582.771346                       NaN
# 135         No      travel_rarely   763.801587                       NaN
# 136         No                NaN  1032.487286                       NaN
# 137         No      travel_rarely   910.309524                       NaN
# 138         No                NaN  1582.771346                    Sales
# 139         No         non-travel   556.256661                       NaN
# 140        Yes  travel_frequently  1582.771346                       NaN
# 141         No  travel_frequently   556.256661                       NaN
# 142         No      travel_rarely   369.261905   Research & Development
# 143         No      travel_rarely  1834.341270                       NaN
# 144         No      travel_rarely   556.256661                       NaN
# 145         No                NaN  1879.119048                       NaN
# 146         No         non-travel  1400.801587                       NaN
# 147         No      travel_rarely  1979.920635                       NaN
# 148         No  travel_frequently   556.256661          Human Resources
# 149         No                NaN  1766.658730                       NaN
# 150         No      travel_rarely  1979.611111                       NaN
# 151         No                NaN  1582.771346                       NaN
# 152        Yes                NaN  1032.571429                       NaN
# 153         No                NaN  1032.487286                       NaN
# 154         No      travel_rarely   824.158730          Human Resources
# 155         No                NaN   556.256661                       NaN
# 156         No  travel_frequently   290.035510                       NaN
# 157         No      travel_rarely   556.256661                       NaN
# 158        Yes      travel_rarely   556.256661                       NaN
# 159         No  travel_frequently  1582.771346                       NaN
# 160         No      travel_rarely   730.785714                       NaN
# 161         No                NaN   487.293651                       NaN
# 162         No      travel_rarely   351.515873                       NaN
# 163        Yes                NaN   556.256661                       NaN
# 164         No      travel_rarely   302.198413                       NaN
# 165         No                NaN   556.256661                       NaN
# 166         No         non-travel  1582.771346                       NaN
# 167         No      travel_rarely   556.256661                    Sales
# 168         No      travel_rarely  1032.487286                       NaN
# 169         No                NaN  1973.984127                       NaN
# 170         No                NaN   556.256661   Research & Development
# 171         No                NaN   556.256661                       NaN
# 172        Yes                NaN   290.035510   Research & Development
# 173         No      travel_rarely  1241.293651                       NaN
# 174         No      travel_rarely  1591.674603                       NaN
# 175         No  travel_frequently  1032.487286                       NaN
# 176         No  travel_frequently   556.256661                       NaN
# 177         No                NaN  1032.487286                       NaN
# 178         No      travel_rarely   635.761905   Research & Development
# 179         No      travel_rarely   528.873016                       NaN
# 180        Yes                NaN   992.436508                    Sales
# 181         No      travel_rarely   556.256661                       NaN
# 182         No                NaN   516.904762                       NaN
# 183         No      travel_rarely  1032.487286                       NaN
# 184         No                NaN  1032.487286                       NaN
# 185         No      travel_rarely   290.035510   Research & Development
# 186         No      travel_rarely  1963.722222                       NaN
# 187         No                NaN  1582.771346                       NaN
# 188        Yes      travel_rarely  1073.015873                       NaN
# 189         No         non-travel  1032.487286   Research & Development
# 190         No                NaN  1032.487286                       NaN
# 191         No                NaN   288.166667                       NaN
# 192         No                NaN   556.256661                       NaN
# 193         No         non-travel   585.412698                       NaN
# 194         No      travel_rarely   556.256661                       NaN
# 195         No                NaN  1032.487286                       NaN
# 196         No      travel_rarely   556.256661                       NaN
# 197         No                NaN  1980.642857                       NaN
# 198         No                NaN  1973.984127                       NaN
# 199         No                NaN   867.904762                       NaN
# 200         No      travel_rarely  1032.487286   Research & Development
# 201        Yes                NaN   345.428571                       NaN
# 202         No                NaN   290.035510                       NaN
# 203         No                NaN   547.753968   Research & Development
# 204         No                NaN   556.256661                       NaN
# 205        Yes                NaN   789.698413                    Sales
# 206         No                NaN  1321.460317                       NaN
# 207         No      travel_rarely   556.256661                       NaN
# 208         No                NaN  1582.771346   Research & Development
# 209         No                NaN   556.256661                       NaN
# 210         No                NaN   679.507937                       NaN
# 211         No         non-travel   556.256661                    Sales
# 212         No      travel_rarely   259.896825                       NaN
# 213         No                NaN  1764.182540                       NaN
# 214         No         non-travel  1582.771346                       NaN
# 215         No         non-travel   556.256661                       NaN
# 216         No      travel_rarely  1032.487286   Research & Development
# 217         No                NaN  1353.650794                       NaN
# 218        Yes                NaN  1032.487286                       NaN
# 219         No                NaN   323.039683                       NaN
# 220         No                NaN   556.256661   Research & Development
# 221         No      travel_rarely  1032.487286                       NaN
# 222         No  travel_frequently   458.507937                       NaN
# 223         No         non-travel   688.587302                       NaN
# 224         No         non-travel  1016.476190                       NaN
# 225         No         non-travel  1842.801587                       NaN
# 226         No      travel_rarely   556.256661                       NaN
# 227         No                NaN   556.256661                       NaN
# 228         No      travel_rarely  1973.984127                       NaN
# 229        Yes  travel_frequently   768.238095                       NaN
# 230         No         non-travel  1419.373016                       NaN
# 231         No                NaN  1712.492063                       NaN
# 232         No                NaN  1582.771346   Research & Development
# 233         No      travel_rarely  1032.487286                       NaN
# 234         No                NaN   442.103175                       NaN
# 235         No  travel_frequently  1044.539683                       NaN
# 236         No                NaN  1032.487286                       NaN
# 237        Yes      travel_rarely  1002.238095                       NaN
# 238         No      travel_rarely  1023.904762                       NaN
# 239         No                NaN  1160.198413                       NaN
# 240         No      travel_rarely   316.642857                       NaN
# 241         No      travel_rarely   556.256661                       NaN
# 242         No      travel_rarely  1582.771346   Research & Development
# 243         No      travel_rarely   953.436508                       NaN
# 244         No                NaN   667.746032                       NaN
# 245         No      travel_rarely  1973.984127                       NaN
# 246         No                NaN   315.198413                       NaN
# 247         No                NaN   858.515873                       NaN
# 248         No                NaN   324.277778                       NaN
# 249         No      travel_rarely   556.256661                       NaN
# 250         No  travel_frequently   290.035510   Research & Development
# 251         No      travel_rarely   885.031746                       NaN
# 252         No      travel_rarely   556.256661                       NaN
# 253         No                NaN   433.023810                       NaN
# 254         No      travel_rarely   556.256661   Research & Development
# 255         No      travel_rarely  1020.190476                       NaN
# 256         No                NaN   556.256661   Research & Development
# 257         No                NaN   556.256661                       NaN
# 258         No      travel_rarely  1376.452381                       NaN
# 259         No      travel_rarely   585.722222                       NaN
# 260         No      travel_rarely   290.035510                       NaN
# 261         No                NaN  1032.487286   Research & Development
# 262         No         non-travel   290.035510                       NaN
# 263         No  travel_frequently   556.256661                       NaN
# 264         No  travel_frequently   300.134921                       NaN
# 265         No                NaN   290.035510                       NaN
# 266         No  travel_frequently   982.841270   Research & Development
# 267         No      travel_rarely   556.256661   Research & Development
# 268         No                NaN   704.166667                       NaN
# 269         No                NaN   556.256661   Research & Development
# 270         No      travel_rarely   456.444444                       NaN
# 271         No                NaN   561.373016                       NaN
# 272        Yes  travel_frequently   626.682540                       NaN
# 273         No                NaN  1032.487286                       NaN
# 274         No  travel_frequently   290.035510                       NaN
# 275         No         non-travel   634.111111                       NaN
# 276        Yes                NaN   636.793651                       NaN
# 277         No      travel_rarely  1032.487286                       NaN
# 278         No      travel_rarely   290.035510                       NaN
# 279         No                NaN   481.619048                       NaN
# 280         No  travel_frequently   578.293651                       NaN
# 281         No      travel_rarely   556.256661                    Sales
# 282         No         non-travel   445.611111   Research & Development
# 283         No  travel_frequently   290.035510   Research & Development
# 284         No      travel_rarely   290.035510   Research & Development
# 285         No      travel_rarely  1582.771346                       NaN
# 286         No      travel_rarely   290.035510                       NaN
# 287         No                NaN   367.714286                       NaN
# 288         No                NaN   645.976190                       NaN
# 289         No         non-travel   702.000000                       NaN
# 290         No                NaN   556.256661                       NaN
# 291         No                NaN  1032.487286                    Sales
# 292         No                NaN  1032.487286                       NaN
# 293        Yes      travel_rarely   290.035510                       NaN
# 294         No                NaN  1973.984127                       NaN
# 295         No                NaN  2005.301587   Research & Development
# 296         No         non-travel   556.256661                    Sales
# 297         No                NaN  1582.771346                       NaN
# 298         No      travel_rarely  1582.771346                       NaN
# 299        Yes         non-travel  1032.487286                       NaN
# 300         No                NaN  1032.487286                       NaN
# 301         No  travel_frequently   556.256661                       NaN
# 302         No      travel_rarely   556.256661   Research & Development
# 303        Yes      travel_rarely   601.301587                       NaN
# 304         No      travel_rarely   556.256661                       NaN
# 305         No  travel_frequently   253.293651                       NaN
# 306         No      travel_rarely   556.256661                       NaN
# 307         No                NaN   521.547619                       NaN
# 308         No                NaN   483.063492                       NaN
# 309         No  travel_frequently   542.388889   Research & Development
# 310        Yes      travel_rarely   218.626984                       NaN
# 311         No                NaN   556.256661                    Sales
# 312         No      travel_rarely   556.256661                       NaN
# 313         No                NaN   616.365079                       NaN
# 314         No      travel_rarely   556.256661                       NaN
# 315         No      travel_rarely   290.035510                       NaN
# 316        Yes                NaN   556.256661                       NaN
# 317         No      travel_rarely   556.256661                       NaN
# 318         No                NaN   313.031746                       NaN
# 319         No                NaN  1363.142857                       NaN
# 320         No      travel_rarely   865.841270                    Sales
# 321         No                NaN   556.256661                       NaN
# 322         No         non-travel   290.035510                       NaN
# 323         No      travel_rarely  1032.487286                       NaN
# 324         No      travel_rarely   417.960317                       NaN
# 325         No      travel_rarely   495.753968                       NaN
# 326        Yes  travel_frequently   282.801587                       NaN
# 327         No                NaN   556.256661                       NaN
# 328         No                NaN   550.642857                       NaN
# 329         No      travel_rarely   556.256661                       NaN
# 330         No  travel_frequently   556.256661                       NaN
# 331         No                NaN   556.256661                    Sales
# 332         No      travel_rarely   973.349206                       NaN
# 333         No                NaN  1032.487286                       NaN
# 334         No      travel_rarely   556.256661                    Sales
# 335         No                NaN   290.035510   Research & Development
# 336         No                NaN  1032.487286                       NaN
# 337         No                NaN   556.256661                       NaN
# 338         No                NaN   556.730159                       NaN
# 339         No      travel_rarely   556.256661                       NaN
# 340         No      travel_rarely  1032.487286                       NaN
# 341         No      travel_rarely  1151.325397                       NaN
# 342         No                NaN   511.746032                       NaN
# 343         No  travel_frequently   907.214286                       NaN
# 344         No                NaN  1979.817460                       NaN
# 345        Yes                NaN   228.634921   Research & Development
# 346         No                NaN  1208.484127   Research & Development
# 347         No                NaN   547.238095                       NaN
# 348         No      travel_rarely  1145.547619                       NaN
# 349         No      travel_rarely   684.253968                       NaN
# 350         No         non-travel   782.785714                       NaN
# 351         No                NaN   447.261905                       NaN
# 352         No                NaN   616.984127                       NaN
# 353         No                NaN   437.873016                       NaN
# 354         No  travel_frequently  1973.984127                       NaN
# 355         No      travel_rarely   539.396825                       NaN
# 356         No      travel_rarely   278.571429                       NaN
# 357        Yes                NaN   556.256661                       NaN
# 358         No                NaN   556.256661                    Sales
# 359        Yes                NaN   244.111111                       NaN
# 360         No                NaN   290.035510                       NaN
# 361        Yes                NaN   290.035510   Research & Development
# 362         No      travel_rarely   240.293651                       NaN
# 363         No  travel_frequently   443.031746                    Sales
# 364         No                NaN   556.256661                       NaN
# 365         No                NaN   693.849206                       NaN
# 366        Yes      travel_rarely  1065.277778                       NaN
# 367         No         non-travel   458.817460                       NaN
# 368         No      travel_rarely  1032.487286                       NaN
# 369         No         non-travel   556.256661                       NaN
# 370         No                NaN  1118.928571                       NaN
# 371         No      travel_rarely  1032.487286                       NaN
# 372         No      travel_rarely  1032.487286                       NaN
# 373         No                NaN   564.571429                       NaN
# 374         No  travel_frequently   658.769841                       NaN
# 375         No         non-travel   654.849206                    Sales
# 376         No         non-travel   290.035510                       NaN
# 377         No  travel_frequently   776.388889                       NaN
# 378         No      travel_rarely   556.256661                       NaN
# 379         No                NaN  1582.771346                       NaN
# 380        Yes         non-travel  1032.487286                       NaN
# 381         No      travel_rarely   377.619048                       NaN
# 382        Yes                NaN  1032.487286                       NaN
# 383        Yes  travel_frequently   556.256661   Research & Development
# 384        Yes                NaN   290.035510   Research & Development
# 385         No                NaN   901.746032                    Sales
# 386         No                NaN  1032.487286                       NaN
# 387         No  travel_frequently  1032.487286                       NaN
# 388        Yes  travel_frequently  1582.771346   Research & Development
# 389         No      travel_rarely  1973.984127                       NaN
# 390         No      travel_rarely   556.256661                       NaN
# 391         No                NaN  1392.753968                       NaN
# 392         No      travel_rarely   290.035510                       NaN
# 393         No      travel_rarely  1032.487286                       NaN
# 394         No                NaN  1973.984127   Research & Development
# 395         No                NaN   556.256661                       NaN
# 396         No                NaN   556.256661                       NaN
# 397         No                NaN   290.035510   Research & Development
# 398         No      travel_rarely   360.182540                       NaN
# 399         No                NaN   538.571429                       NaN
# 400         No                NaN   556.256661                       NaN
# 401         No                NaN  1057.746032                       NaN
# 402         No      travel_rarely   290.035510                       NaN
# 403         No                NaN  2036.666667   Research & Development
# 404         No      travel_rarely  1582.771346                       NaN
# 405         No                NaN  1032.487286                       NaN
# 406         No      travel_rarely  1032.487286                       NaN
# 407        Yes      travel_rarely  1032.487286                       NaN
# 408        Yes                NaN   290.035510   Research & Development
# 409         No      travel_rarely   640.611111                       NaN
# 410         No      travel_rarely   731.920635                       NaN
# 411        Yes                NaN  1032.487286                    Sales
# 412         No      travel_rarely   467.793651                       NaN
# 413         No                NaN   876.984127                       NaN
# 414         No                NaN   556.256661                       NaN
# 415         No  travel_frequently   478.626984                    Sales
# 416         No                NaN   553.325397                       NaN
# 417        Yes                NaN  1582.771346                       NaN
# 418         No                NaN   556.256661                       NaN
# 419         No                NaN   421.055556                       NaN
# 420         No      travel_rarely  1582.771346                       NaN
# 421         No      travel_rarely   369.158730                       NaN
# 422        Yes                NaN  1032.487286                       NaN
# 423         No                NaN  1787.809524   Research & Development
# 424         No                NaN  1582.771346                       NaN
# 425         No         non-travel   556.256661                       NaN
# 426         No                NaN  1113.563492                       NaN
# 427        Yes                NaN  1032.487286                       NaN
# 428         No      travel_rarely  1119.547619                       NaN
# 429         No      travel_rarely  1079.825397                       NaN
# 430         No      travel_rarely   556.256661                       NaN
# 431        Yes                NaN   243.698413                       NaN
# 432         No                NaN   556.256661                       NaN
# 433         No      travel_rarely  1582.771346          Human Resources
# 434         No                NaN   664.341270                    Sales
# 435        Yes                NaN  1032.487286                       NaN
# 436         No                NaN  1973.984127                       NaN
# 437         No                NaN   595.214286                       NaN
# 438         No         non-travel   452.420635                       NaN
# 439         No  travel_frequently   556.256661                       NaN
# 440         No                NaN   556.256661   Research & Development
# 441         No                NaN   419.507937   Research & Development
# 442         No      travel_rarely   556.256661                       NaN
# 443         No                NaN   556.256661                       NaN
# 444         No                NaN   537.126984                       NaN
# 445         No                NaN  1582.771346                       NaN
# 446        Yes  travel_frequently   273.928571                       NaN
# 447         No                NaN   265.158730                       NaN
# 448         No      travel_rarely  1032.487286                       NaN
# 449         No                NaN   464.492063                       NaN
# 450         No                NaN   556.256661   Research & Development
# 451         No                NaN   556.256661                       NaN
# 452         No  travel_frequently   512.571429                       NaN
# 453         No                NaN  1032.487286                       NaN
# 454         No         non-travel   531.039683                       NaN
# 455         No                NaN   280.428571                       NaN
# 456         No      travel_rarely   365.134921                       NaN
# 457         No      travel_rarely   564.158730                       NaN
# 458        Yes                NaN   599.753968                       NaN
# 459         No         non-travel   556.256661   Research & Development
# 460         No                NaN   997.388889                       NaN
# 461        Yes      travel_rarely   556.256661                       NaN
# 462         No         non-travel   531.761905                       NaN
# 463         No  travel_frequently   585.515873                       NaN
# 464        Yes                NaN   754.619048                       NaN
# 465         No      travel_rarely  1582.771346   Research & Development
# 466         No      travel_rarely   556.256661                    Sales
# 467         No                NaN  1032.487286                       NaN
# 468         No  travel_frequently   290.035510                       NaN
# 469         No  travel_frequently   556.256661                       NaN
# 470         No                NaN   556.256661                       NaN
# 471         No      travel_rarely  1032.487286                       NaN
# 472         No                NaN   290.035510   Research & Development
# 473         No      travel_rarely   556.256661                       NaN
# 474        Yes  travel_frequently   556.256661                    Sales
# 475         No  travel_frequently   556.256661                       NaN
# 476         No                NaN  1032.487286                       NaN
# 477         No                NaN   525.984127                       NaN
# 478         No      travel_rarely   556.256661                       NaN
# 479         No      travel_rarely   556.256661                       NaN
# 480         No      travel_rarely  1032.487286                       NaN
# 481         No      travel_rarely  1400.079365                       NaN
# 482         No                NaN   692.507937                    Sales
# 483         No      travel_rarely   556.256661                       NaN
# 484         No      travel_rarely  1030.817460                       NaN
# 485         No      travel_rarely  1032.487286                       NaN
# 486         No      travel_rarely  1057.333333                       NaN
# 487         No                NaN   556.256661                       NaN
# 488         No  travel_frequently  1582.771346   Research & Development
# 489         No                NaN  1128.523810   Research & Development
# 490         No      travel_rarely   267.531746                       NaN
# 491         No  travel_frequently  1225.507937   Research & Development
# 492         No      travel_rarely   835.198413                       NaN
# 493        Yes      travel_rarely  1032.487286                       NaN
# 494         No      travel_rarely  1582.771346                       NaN
# 495         No      travel_rarely  1973.984127                       NaN
# 496         No                NaN   556.256661                       NaN
# 497         No      travel_rarely  1739.111111                       NaN
# 498         No      travel_rarely  1582.771346                       NaN
# 499         No      travel_rarely   468.103175                       NaN
# 500         No         non-travel  1849.301587   Research & Development
# 501         No      travel_rarely   414.142857   Research & Development
# 502         No      travel_rarely  1314.650794                       NaN
# 503         No  travel_frequently  1032.487286                       NaN
# 504         No                NaN   348.317460                       NaN
# 505        Yes                NaN  1081.476190          Human Resources
# 506         No                NaN  1582.771346                       NaN
# 507         No      travel_rarely  1032.487286                       NaN
# 508         No                NaN   290.035510                       NaN
# 509         No                NaN   290.035510          Human Resources
# 510         No                NaN   438.388889                       NaN
# 511         No      travel_rarely   675.690476   Research & Development
# 512         No                NaN  1582.771346                       NaN
# 513         No                NaN  1486.849206                       NaN
# 514         No      travel_rarely  2020.777778                       NaN
# 515         No                NaN   849.849206                    Sales
# 516         No                NaN   331.293651   Research & Development
# 517         No                NaN  1723.428571                       NaN
# 518         No                NaN  1032.487286                       NaN
# 519         No                NaN   492.555556                       NaN
# 520         No      travel_rarely  1973.984127                       NaN
# 521         No                NaN   556.256661                    Sales
# 522         No      travel_rarely   556.256661                       NaN
# 523         No         non-travel   471.301587                       NaN
# 524         No                NaN   618.325397                       NaN
# 525         No                NaN   670.531746                       NaN
# 526         No                NaN   356.158730                       NaN
# 527         No      travel_rarely   290.035510                       NaN
# 528         No                NaN   660.007937                       NaN
# 529         No                NaN   556.256661                       NaN
# 530         No  travel_frequently   556.256661                       NaN
# 531         No      travel_rarely   556.256661                    Sales
# 532         No      travel_rarely  1032.487286                       NaN
# 533         No         non-travel  1032.487286                       NaN
# 534         No      travel_rarely   556.256661                       NaN
# 535         No      travel_rarely   281.150794                       NaN
# 536         No                NaN  1973.984127                       NaN
# 537         No                NaN   373.698413                       NaN
# 538         No  travel_frequently   556.256661                       NaN
# 539         No                NaN   637.619048                    Sales
# 540         No                NaN   647.317460                    Sales
# 541         No                NaN   452.007937   Research & Development
# 542         No                NaN  1032.487286                       NaN
# 543         No                NaN   264.023810                       NaN
# 544         No                NaN   566.222222   Research & Development
# 545         No                NaN   259.380952                       NaN
# 546         No  travel_frequently   290.035510   Research & Development
# 547         No                NaN   556.256661                       NaN
# 548         No      travel_rarely   329.746032                       NaN
# 549         No                NaN   290.035510                       NaN
# 550         No      travel_rarely   556.256661   Research & Development
# 551         No                NaN   290.035510   Research & Development
# 552         No      travel_rarely   352.857143                       NaN
# 553         No                NaN   290.035510   Research & Development
# 554         No                NaN   421.674603                       NaN
# 555         No                NaN   556.256661                       NaN
# 556         No         non-travel   553.841270                       NaN
# 557        Yes                NaN  1334.666667                    Sales
# 558        Yes                NaN   556.256661                       NaN
# 559         No      travel_rarely   290.035510   Research & Development
# 560         No      travel_rarely   290.035510                       NaN
# 561         No      travel_rarely   556.256661                       NaN
# 562         No      travel_rarely   290.035510                       NaN
# 563         No                NaN  1032.487286                       NaN
# 564         No                NaN   435.500000                       NaN
# 565        Yes      travel_rarely   556.256661                       NaN
# 566        Yes                NaN   512.055556                       NaN
# 567         No                NaN   290.035510   Research & Development
# 568        Yes                NaN   433.333333                       NaN
# 569         No      travel_rarely   290.035510                       NaN
# 570         No      travel_rarely  1973.984127                       NaN
# 571         No                NaN   290.035510                       NaN
# 572         No      travel_rarely   516.492063                       NaN
# 573         No                NaN   290.035510                       NaN
# 574        Yes                NaN   788.150794                       NaN
# 575         No         non-travel   556.256661   Research & Development
# 576        Yes                NaN   290.035510                       NaN
# 577        Yes                NaN   290.035510                       NaN
# 578         No                NaN   670.841270                       NaN
# 579         No                NaN  1973.984127   Research & Development
# 580         No  travel_frequently  1395.436508                       NaN
# 581         No                NaN   556.256661                       NaN
# 582         No         non-travel   655.055556                       NaN
# 583         No      travel_rarely   556.256661                       NaN
# 584         No      travel_rarely   290.035510                       NaN
# 585        Yes                NaN   658.253968                       NaN
# 586         No                NaN  1582.771346                       NaN
# 587        Yes  travel_frequently   320.047619                       NaN
# 588         No      travel_rarely   556.256661                       NaN
# 589         No                NaN   556.256661                    Sales
# 590         No                NaN   556.256661                       NaN
# 591         No      travel_rarely  1032.487286                       NaN
# 592         No  travel_frequently   470.063492                       NaN
# 593         No      travel_rarely   556.256661                       NaN
# 594         No      travel_rarely   436.428571                       NaN
# 595         No      travel_rarely  1032.487286                       NaN
# 596         No      travel_rarely   501.325397                    Sales
# 597         No                NaN   290.035510                       NaN
# 598         No      travel_rarely   652.269841                       NaN
# 599        Yes                NaN   556.256661                       NaN
# 600         No  travel_frequently   290.035510                       NaN
# 601         No                NaN  1110.261905                       NaN
# 602         No      travel_rarely   290.035510                       NaN
# 603         No                NaN   290.035510                       NaN
# 604         No  travel_frequently   306.738095                       NaN
# 605         No      travel_rarely   536.920635                       NaN
# 606         No                NaN   556.256661                       NaN
# 607         No      travel_rarely  1032.487286                       NaN
# 608         No                NaN  1795.134921                       NaN
# 609         No      travel_rarely  1032.487286                    Sales
# 610         No                NaN  1032.487286                       NaN
# 611         No                NaN   290.035510                       NaN
# 612         No                NaN  1742.103175                       NaN
# 613         No                NaN   556.256661   Research & Development
# 614         No      travel_rarely   446.023810                       NaN
# 615         No      travel_rarely   531.865079                    Sales
# 616        Yes                NaN   302.920635                       NaN
# 617         No      travel_rarely   290.035510                       NaN
# 618         No                NaN   290.035510                       NaN
# 619         No  travel_frequently  1032.487286                       NaN
# 620         No                NaN  1938.547619                    Sales
# 621         No         non-travel   556.256661                       NaN
# 622        Yes      travel_rarely   503.801587                       NaN
# 623        Yes                NaN  1032.487286                       NaN
# 624         No         non-travel   209.341270                       NaN
# 625         No      travel_rarely   556.256661                    Sales
# 626         No                NaN   309.111111                       NaN
# 627         No                NaN   556.256661                    Sales
# 628         No         non-travel  1032.487286   Research & Development
# 629         No      travel_rarely   290.035510                       NaN
# ...
# 789         Yes
# 790         Yes
# 791           0
# 792           1
# 793         Yes
# 794           1
# 795           0
# 796         Yes
# 797           0
# 798           1
# 799        True
# 800           1
# 801        True
# 802           1
# 803           1
# 804           1
# 805           0
# 806           0
# 807           0
# 808           1
# 809           1
# 810           1
# 811       False
# 812           0
# 813           1
# 814         Yes
# 815         Yes
# 816        True
# 817        True
# 818           1
# 819        True
# 820        True
# 821           0
# 822        True
# 823         Yes
# 824       False
# 825        True
# 826           0
# 827       False
# 828       False
# 829       False
# 830           1
# 831           1
# 832           1
# 833         Yes
# 834        True
# 835           1
# 836           1
# 837         Yes
# 838        True
# 839           0
# 840       False
# 841         Yes
# 842           0
# 843        True
# 844           0
# 845         Yes
# 846           1
# 847        True
# 848       False
# 849           0
# 850           1
# 851        True
# 852       False
# 853        True
# 854           0
# 855        True
# 856        True
# 857         Yes
# 858         Yes
# 859        True
# 860           0
# 861           0
# 862           0
# 863           1
# 864           0
# 865           0
# 866       False
# 867       False
# 868        True
# 869        True
# 870           0
# 871           1
# 872       False
# 873        True
# 874       False
# 875        True
# 876       False
# 877        True
# 878         Yes
# 879           0
# 880       False
# 881           0
# 882         Yes
# 883           1
# 884           1
# 885        True
# 886           0
# 887           1
# 888         Yes
# 889         Yes
# 890           1
# 891        True
# 892         Yes
# 893           0
# 894           1
# 895        True
# 896           1
# 897           0
# 898         Yes
# 899           1
# 900       False
# 901        True
# 902           1
# 903         Yes
# 904           0
# 905           0
# 906           0
# 907        True
# 908       False
# 909         Yes
# 910           1
# 911         Yes
# 912           1
# 913           1
# 914           0
# 915       False
# 916           1
# 917           1
# 918        True
# 919        True
# 920        True
# 921         Yes
# 922        True
# 923           0
# 924           1
# 925        True
# 926       False
# 927           0
# 928         Yes
# 929         Yes
# 930           0
# 931        True
# 932           0
# 933         Yes
# 934           1
# 935        True
# 936           0
# 937           0
# 938       False
# 939           0
# 940       False
# 941           1
# 942       False
# 943         Yes
# 944        True
# 945         Yes
# 946           1
# 947         Yes
# 948       False
# 949       False
# 950           1
# 951           1
# 952        True
# 953       False
# 954         Yes
# 955        True
# 956           0
# 957           0
# 958       False
# 959        True
# 960           0
# 961       False
# 962       False
# 963           1
# 964           0
# 965           1
# 966       False
# 967           1
# 968           1
# 969        True
# 970         Yes
# 971         Yes
# 972       False
# 973           1
# 974         Yes
# 975           0
# 976           0
# 977       False
# 978           1
# 979           0
# 980           0
# 981        True
# 982         Yes
# 983       False
# 984         Yes
# 985           0
# 986         Yes
# 987       False
# 988           1
# 989       False
# 990        True
# 991           1
# 992           0
# 993           0
# 994         Yes
# 995           1
# 996         Yes
# 997           1
# 998       False
# 999           0
# 1000       True
# 1001          1
# 1002        Yes
# 1003          1
# 1004      False
# 1005          1
# 1006       True
# 1007          1
# 1008       True
# 1009       True
# 1010          1
# 1011          1
# 1012       True
# 1013        Yes
# 1014          1
# 1015          0
# 1016          1
# 1017          1
# 1018        Yes
# 1019          0
# 1020      False
# 1021          0
# 1022          0
# 1023      False
# 1024          1
# 1025      False
# 1026       True
# 1027          1
# 1028          1
# 1029      False
# 1030        Yes
# 1031       True
# 1032          0
# 1033        Yes
# 1034          1
# 1035      False
# 1036          1
# 1037        Yes
# 1038       True
# 1039          1
# 1040          0
# 1041          1
# 1042      False
# 1043          1
# 1044          1
# 1045       True
# 1046          1
# 1047       True
# 1048          1
# 1049        Yes
# 1050      False
# 1051       True
# 1052       True
# 1053          1
# 1054       True
# 1055        Yes
# 1056          0
# 1057      False
# 1058          0
# 1059          1
# 1060          0
# 1061      False
# 1062       True
# 1063          1
# 1064       True
# 1065       True
# 1066      False
# 1067       True
# 1068          1
# 1069      False
# 1070      False
# 1071          0
# 1072       True
# 1073          0
# 1074       True
# 1075          1
# 1076      False
# 1077       True
# 1078          1
# 1079      False
# 1080          0
# 1081          1
# 1082          1
# 1083          0
# 1084        Yes
# 1085          0
# 1086      False
# 1087       True
# 1088          1
# 1089          1
# 1090      False
# 1091          0
# 1092        Yes
# 1093          1
# 1094          1
# 1095        Yes
# 1096       True
# 1097       True
# 1098          1
# 1099       True
# 1100          1
# 1101       True
# 1102          1
# 1103      False
# 1104      False
# 1105       True
# 1106      False
# 1107          1
# 1108        Yes
# 1109          0
# 1110      False
# 1111        Yes
# 1112          1
# 1113          0
# 1114      False
# 1115      False
# 1116        Yes
# 1117      False
# 1118          1
# 1119      False
# 1120       True
# 1121       True
# 1122          1
# 1123      False
# 1124      False
# 1125          1
# 1126      False
# 1127      False
# 1128      False
# 1129        Yes
# 1130        Yes
# 1131      False
# 1132      False
# 1133       True
# 1134          1
# 1135       True
# 1136          0
# 1137        Yes
# 1138      False
# 1139       True
# 1140          1
# 1141        Yes
# 1142          0
# 1143          1
# 1144      False
# 1145        Yes
# 1146      False
# 1147      False
# 1148        Yes
# 1149       True
# 1150          0
# 1151      False
# 1152          1
# 1153          1
# 1154          1
# 1155       True
# 1156          1
# 1157      False
# 1158        Yes
# 1159       True
# 1160       True
# 1161        Yes
# 1162       True
# 1163        Yes
# 1164          0
# 1165        Yes
# 1166        Yes
# 1167      False
# 1168          0
# 1169          0
# 1170        Yes
# 1171       True
# 1172        Yes
# 1173          1
# 1174        Yes
# 1175        Yes
# 1176          1
# 1177        Yes
# 1178        Yes
# 1179          1
# 1180        Yes
# 1181      False
# 1182      False
# 1183      False
# 1184          1
# 1185          1
# 1186       True
# 1187          0
# 1188          1
# 1189          1
# 1190       True
# 1191          1
# 1192       True
# 1193      False
# 1194          0
# 1195        Yes
# 1196      False
# 1197          0
# 1198      False
# 1199          0
# 1200       True
# 1201          1
# 1202      False
# 1203        Yes
# 1204      False
# 1205       True
# 1206      False
# 1207      False
# 1208       True
# 1209          0
# 1210          0
# 1211      False
# 1212       True
# 1213          0
# 1214       True
# 1215          0
# 1216          1
# 1217      False
# 1218          0
# 1219        Yes
# 1220      False
# 1221       True
# 1222          0
# 1223        Yes
# 1224        Yes
# 1225          0
# 1226       True
# 1227       True
# 1228       True
# 1229      False
# 1230        Yes
# 1231          0
# 1232       True
# 1233      False
# 1234          1
# 1235      False
# 1236          0
# 1237          0
# 1238       True
# 1239      False
# 1240       True
# 1241        Yes
# 1242        Yes
# 1243       True
# 1244          1
# 1245          0
# 1246        Yes
# 1247          0
# 1248        Yes
# 1249      False
# 1250          0
# 1251      False
# 1252       True
# 1253          0
# 1254        Yes
# 1255       True
# 1256          0
# 1257        Yes
# 1258          0
# 1259        Yes
# 1260        Yes
# 1261       True
# 1262      False
# 1263          0
# 1264      False
# 1265        Yes
# 1266      False
# 1267          1
# 1268          0
# 1269          1
# 1270       True
# 1271      False
# 1272       True
# 1273       True
# 1274          0
# 1275        Yes
# 1276        Yes
# 1277          1
# 1278       True
# 1279          0
# 1280       True
# 1281       True
# 1282      False
# 1283          0
# 1284       True
# 1285        Yes
# 1286          0
# 1287          1
# 1288      False
# 1289       True
# 1290          0
# 1291        Yes
# 1292      False
# 1293       True
# 1294          1
# 1295      False
# 1296      False
# 1297       True
# 1298        Yes
# 1299       True
# 1300      False
# 1301          1
# 1302          0
# 1303       True
# 1304       True
# 1305        Yes
# 1306       True
# 1307        Yes
# 1308       True
# 1309          0
# 1310        Yes
# 1311          0
# 1312          1
# 1313          0
# 1314      False
# 1315          0
# 1316          1
# 1317          0
# 1318        Yes
# 1319          1
# 1320          0
# 1321       True
# 1322        Yes
# 1323          1
# 1324      False
# 1325      False
# 1326          1
# 1327          1
# 1328          1
# 1329       True
# 1330       True
# 1331       True
# 1332          1
# 1333        Yes
# 1334      False
# 1335          1
# 1336       True
# 1337          0
# 1338      False
# 1339        Yes
# 1340      False
# 1341          0
# 1342       True
# 1343      False
# 1344          1
# 1345      False
# 1346      False
# 1347       True
# 1348          0
# 1349          1
# 1350          1
# 1351          0
# 1352       True
# 1353          0
# 1354        Yes
# 1355          1
# 1356          1
# 1357          0
# 1358       True
# 1359          1
# 1360          1
# 1361        Yes
# 1362          0
# 1363          0
# 1364          0
# 1365       True
# 1366          1
# 1367        Yes
# 1368          0
# 1369        Yes
# 1370          0
# 1371          1
# 1372       True
# 1373       True
# 1374        Yes
# 1375          1
# 1376      False
# 1377          1
# 1378      False
# 1379       True
# 1380       True
# 1381        Yes
# 1382       True
# 1383       True
# 1384        Yes
# 1385      False
# 1386          1
# 1387          0
# 1388      False
# 1389          0
# 1390          1
# 1391          0
# 1392        Yes
# 1393          0
# 1394      False
# 1395          0
# 1396          1
# 1397      False
# 1398      False
# 1399          1
# 1400      False
# 1401       True
# 1402       True
# 1403      False
# 1404        Yes
# 1405      False
# 1406       True
# 1407          0
# 1408          0
# 1409          1
# 1410          0
# 1411       True
# 1412          1
# 1413      False
# 1414      False
# 1415          0
# 1416          0
# 1417       True
# 1418       True
# 1419        Yes
# 1420       True
# 1421        Yes
# 1422          1
# 1423          0
# 1424        Yes
# 1425       True
# 1426          1
# 1427       True
# 1428          0
# 1429        Yes
# 1430          0
# 1431       True
# 1432       True
# 1433        Yes
# 1434      False
# 1435          1
# 1436      False
# 1437      False
# 1438        Yes
# 1439        Yes
# 1440          1
# 1441      False
# 1442       True
# 1443       True
# 1444        Yes
# 1445          1
# 1446          0
# 1447        Yes
# 1448        Yes
# 1449          0
# 1450          1
# 1451      False
# 1452        Yes
# 1453          0
# 1454       True
# 1455          1
# 1456        Yes
# 1457        Yes
# 1458       True
# 1459        Yes
# 1460      False
# 1461      False
# 1462          1
# 1463       True
# 1464        Yes
# 1465          0
# 1466       True
# 1467      False
# 1468      False
# 1469          0
# 1470          1
# 1471      False
# 1472          0
# 1473          1
# 1474        Yes
# 1475        Yes
# 1476        Yes
# 1477          1
# 1478          1
# 1479       True
# 1480          1
# 1481        Yes
# 1482        Yes
# 1483          0
# 1484        Yes
# 1485      False
# 1486          1
# 1487          1
# 1488      False
# 1489        Yes
# 1490          1
# 1491        Yes
# 1492      False
# 1493          0
# 1494          0
# 1495       True
# 1496      False
# 1497        Yes
# 1498       True
# 1499          1
# 1500          1
# 1501          0
# 1502      False
# 1503          0
# 1504       True
# 1505          0
# 1506      False
# 1507        Yes
# 1508       True
# 1509          0
# 1510       True
# 1511        Yes
# 1512          1
# 1513       True
# 1514       True
# 1515      False
# 1516       True
# 1517          1
# 1518      False
# 1519          0
# 1520          0
# 1521          1
# 1522        Yes
# 1523          0
# 1524      False
# 1525        Yes
# 1526      False
# 1527        Yes
# 1528       True
# 1529          0
# 1530       True
# 1531          1
# 1532          1
# 1533       True
# 1534          1
# 1535          1
# 1536          1
# 1537          1
# 1538          1
# 1539       True
# 1540        Yes
# 1541        Yes
# 1542          0
# 1543          1
# 1544        Yes
# 1545        Yes
# 1546          1
# 1547      False
# 1548          0
# 1549          1
# 1550      False
# 1551       True
# 1552      False
# 1553          1
# 1554          1
# 1555        Yes
# 1556        Yes
# 1557          0
# 1558        Yes
# 1559       True
# 1560      False
# 1561          0
# 1562        Yes
# 1563        Yes
# 1564      False
# 1565       True
# 1566          1
# 1567       True
# 1568      False
# 1569        Yes
# 1570        Yes
# 1571      False
# 1572          1
# 1573       True
# 1574      False
# 1575          1
# 1576      False
# 1577          1
# 1578       True
# 1579        Yes
# 1580          0
# 1581       True
# 1582      False
# 1583          0
# 1584          0
# 1585          0
# 1586          1
# 1587          0
# 1588        Yes
# 1589          0
# 1590          0
# 1591       True
# 1592       True
# 1593        Yes
# 1594        Yes
# 1595      False
# 1596        Yes
# 1597          1
# 1598          1
# 1599      False
# 1600        Yes
# 1601          0
# 1602       True
# 1603      False
# 1604        Yes
# 1605       True
# 1606          1
# 1607       True
# 1608          1
# 1609          0
# 1610          1
# 1611        Yes
# 1612       True
# 1613          0
# 1614       True
# 1615      False
# 1616       True
# 1617          0
# 1618          1
# 1619       True
# 1620      False
# 1621       True
# 1622        Yes
# 1623      False
# 1624          0
# 1625          0
# 1626       True
# 1627      False
# 1628        Yes
# 1629       True
# 1630       True
# 1631          1
# 1632       True
# 1633          1
# 1634          1
# 1635       True
# 1636      False
# 1637          1
# 1638       True
# 1639        Yes
# 1640       True
# 1641       True
# 1642          1
# 1643      False
# 1644        Yes
# 1645          1
# 1646          1
# 1647          1
# 1648      False
# 1649          0
# 1650      False
# 1651       True
# 1652          1
# 1653          1
# 1654          1
# 1655        Yes
# 1656       True
# 1657      False
# 1658          1
# 1659       True
# 1660      False
# 1661        Yes
# 1662      False
# 1663        Yes
# 1664        Yes
# 1665          1
# 1666          0
# 1667          1
# 1668       True
# 1669          0
# 1670          0
# 1671       True
# 1672          0
# 1673        Yes
# 1674      False
# 1675      False
# 1676        Yes
# 1677          0

# %% [markdown]
# ### ✨ Plan de normalización y limpieza de columnas
#
# 🖥️ **Columna `remotework`**
# - 🔄 Normalizar valores a `yes` / `no`.
#
# ---
#
# 👫 **Columna `gender`**
# - 🔄 Normalizar valores a `M` / `F`.
#
# ---
#
# 🔤 **Columnas categóricas (texto)**
# - 📝 Corregir fallos tipográficos (ejemplo: combinación de mayúsculas y minúsculas).
# - 🔠 Capitalizar la primera letra de cada valor.
# - ⚙️ Implementar una función que recorra todas las columnas categóricas para normalizar texto.
#
# ---
#
# 🔢 **Columnas numéricas**
# - 🔧 Corregir fallos tipográficos:
#   - ➡️ Reemplazar `,` por `.` en valores numéricos.
#   - 🎯 Redondear decimales a 2 dígitos.
# - ⚙️ Implementar una función que recorra todas las columnas numéricas y normalice sus valores.
#
# ---
#
# 📏 **Columna `distancefromhome`**
# - 🔄 Convertir valores negativos a valor absoluto.
#
# ---
#
# 🔍 **Detección y corrección de valores mal escritos en categóricas**
# - 👀 Identificar valores con `unique()` durante el EDA.
# - ✏️ Reemplazar cada error con la palabra correctamente escrita.
#   - Ejemplo: `marreid` → `married`.
#
# ---
#
# 🏷️ **Nombres de columnas**
# - ✨ Renombrar y normalizar: todas las columnas con formato `.title`.
#   - Ejemplo: `distancefromhome` → `Distancefromhome`.

# %% [markdown]
# ***Una funcioncilla para ver cosas***

# %%
# FUNCIÓN PARA ELIMINAR DUPLICADOS
# MANTIENE LA PRIMERA APARICIÓN Y BORRA LAS DEMÁS FILAS REPETIDAS
# ELIMINAR DUPLICADOS PORQUE INFLAN MUCHO LOS RESULTADOS

def remove_duplicates(df):
    """
    Elimina filas duplicadas de un DataFrame manteniendo la primera aparición.

    Parámetros:
    df (pd.DataFrame): DataFrame de entrada.

    Retorna:
    pd.DataFrame: DataFrame sin duplicados.
    """
    filas_iniciales = len(df)
    df_sin_duplicados = df.drop_duplicates(keep="first")
    filas_finales = len(df_sin_duplicados)
    print(f"Se eliminaron {filas_iniciales - filas_finales} filas duplicadas")
    return df_sin_duplicados

# %%
df_clean = remove_duplicates(df_clean)

# %%
# FUNCIÓN QUE DETECTA COLUMNAS QUE ESTÁN EN FORMATO STRING PERO CONTIENEN VALORES NUMÉRICOS Y
# LAS CONVIERTE A TIPO NUMÉRICO
def convert_numeric_columns(df):
    """
    Detecta columnas que están en formato string pero contienen valores numéricos
    y las convierte automáticamente a tipo numérico.

    Parámetros:
    df (pd.DataFrame): DataFrame de entrada.

    Retorna:
    pd.DataFrame: DataFrame con las columnas convertidas a numéricas.
    """
    for col in df.columns:
        if df[col].dtype == "object":  # posibles columnas mal cargadas
            try:
                df[col] = pd.to_numeric(df[col], errors="coerce")
            except Exception:
                pass  # si no se puede convertir, la deja como está
    return df

# %%
df_clean = convert_numeric_columns(df_clean)

# %% [markdown]
# En esta parte:
# - Quitamos espacios extra en columnas de texto.
# - Organizamos un poco mejor los nombres de roles y departamentos.
# - Creamos columnas nuevas para analizar la antigüedad (que agrupa a los empleados según los años en la empresa. Esto es útil porque no es lo mismo alguien que lleva 1 año que alguien que lleva 20. ) y el teletrabajo (para indicar con un 1 si la persona trabaja en remoto y 0 si no.)

# %%
# LIMPIEZA DE DATOS 

import pandas as pd

# 1. Cargo el dataset original
df = pd.read_csv("ABC_data.csv", index_col=0)

# 2. Hago una copia para trabajar sin tocar el original
df_copy = df.copy()

# 3. Limpio columnas de texto (jobrole y department)
#    - Quito espacios extra
#    - Pongo formato con mayúscula inicial
df_copy["jobrole"] = df_copy["jobrole"].str.strip().str.title()
df_copy["department"] = df_copy["department"].str.strip().str.title()

# 4. Creo una nueva columna de antigüedad agrupada (TenureGroup)
#    Agrupo los años en la empresa en intervalos (0-2, 3-5, 6-10, etc.)
bins = [0,2,5,10,20,40]                        # límites de los grupos
labels = ["0-2","3-5","6-10","11-20","20+"]    # nombres de los grupos
df_copy["TenureGroup"] = pd.cut(df_copy["yearsatcompany"], 
                                bins=bins, labels=labels, include_lowest=True)

# 5. Creo una nueva columna para teletrabajo (RemoteWork_flag)
#    Si la persona trabaja en remoto → 1, si no → 0
df_copy["RemoteWork_flag"] = df_copy["remotework"].astype(str).str.lower().isin(["yes","1","true"]).astype(int)

# 6. Muestro las primeras filas para comprobar la limpieza
df_copy.head()

# %%
attrition_by_tenure = df_copy.groupby("TenureGroup")["attrition"].apply(lambda x: (x=="Yes").mean())
print(attrition_by_tenure)

# %%
attrition_by_remote = df_copy.groupby("RemoteWork_flag")["attrition"].apply(lambda x: (x=="Yes").mean())
print(attrition_by_remote)

# %%
pip install matplotlib

# %%
# VISUALIZACIONES


import matplotlib.pyplot as plt   # 👈 esto es lo que faltaba

# 1. Attrition por TenureGroup
attrition_by_tenure = df_copy.groupby("TenureGroup")["attrition"].apply(lambda x: (x=="Yes").mean())

attrition_by_tenure.plot(kind="bar", title="Attrition por antigüedad (TenureGroup)")
plt.ylabel("Tasa de attrition")
plt.show()

# 2. Attrition por RemoteWork_flag
attrition_by_remote = df_copy.groupby("RemoteWork_flag")["attrition"].apply(lambda x: (x=="Yes").mean())

attrition_by_remote.plot(kind="bar", title="Attrition por teletrabajo (0 = No, 1 = Sí)")
plt.ylabel("Tasa de attrition")
plt.show()

# %% [markdown]
# - La **antigüedad en la empresa** influye bastante en el abandono:
#   los empleados más nuevos (0-2 años) tienen más probabilidad de irse, mientras que quienes llevan más años tienden a quedarse.
#
# - El **teletrabajo** también marca una diferencia:
#   hay variaciones claras en la tasa de abandono entre quienes trabajan remoto y quienes no.
#
# Esto es solo un primer análisis, pero ya da pistas de factores importantes para estudiar más a fondo.
